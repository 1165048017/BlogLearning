# %%
import sys, os
sys.path.append(os.pardir)

# %matplotlib inline
import matplotlib.pyplot as plt
import time
from PIL import Image
from src.detect import FaceDetector
from src.utils import set_figsize, show_bboxes

# %%
img = Image.open('../assets/office1.jpg')
detector = FaceDetector()
start = time.time()
bounding_boxes = detector.detect(img)
print("time %.2f sec" % (time.time() - start))
show_bboxes(img, bounding_boxes)
# Out:
# time 1.08 sec
# <PIL.Image.Image image mode=RGB size=899x399 at 0x7FF31EF108D0>

# %%
img = Image.open('../assets/office2.jpg')
start = time.time()
bounding_boxes = detector.detect(img)
print("time %.2f sec" % (time.time() - start))
show_bboxes(img, bounding_boxes)
# Out:
# time 0.23 sec
# <PIL.Image.Image image mode=RGB size=1280x720 at 0x7FF31EF03588>

# %%
img = Image.open('../assets/office3.jpg')
start = time.time()
bounding_boxes = detector.detect(img)
print("time %.2f sec" % (time.time() - start))
show_bboxes(img, bounding_boxes)
# Out:
# time 0.10 sec
# <PIL.Image.Image image mode=RGB size=570x380 at 0x7FF39C5CCE80>

# %%
img = Image.open('../assets/office4.jpg')
start = time.time()
bounding_boxes = detector.detect(img)
print("time %.2f sec" % (time.time() - start))
show_bboxes(img, bounding_boxes)
# Out:
# time 0.21 sec
# <PIL.Image.Image image mode=RGB size=615x407 at 0x7FF31EF03400>

# %%
img = Image.open('../assets/office5.jpg')
start = time.time()
bounding_boxes = detector.detect(img, min_face_size=15.0)
print("time %.2f sec" % (time.time() - start))
show_bboxes(img, bounding_boxes)
# Out:
# time 0.23 sec
# <PIL.Image.Image image mode=RGB size=500x375 at 0x7FF31DB2C748>
